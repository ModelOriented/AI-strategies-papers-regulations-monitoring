# %%
import spacy
import os

from mars.definition_extraction import DeftCorpusLoader
import pandas as pd
import numpy as np
from sklearn import metrics
# Out:
# /home/jakwisn/.cache/pypoetry/virtualenvs/mars-48yr609M-py3.8/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
os.chdir('../..')

# %%
STORAGE_PATH = "mars/definition_extraction/deft_corpus/data"

deft_loader = DeftCorpusLoader(STORAGE_PATH)
trainframe, devframe = deft_loader.load_classification_data(preprocess=True, clean=True)
testframe = deft_loader.load_test_data()

# %%
nlp = spacy.load('mars/definition_extraction/output/model-best')

# %%
def get_preds(frame):
    probs = []
    frame = frame.reset_index(drop=True)
    for i in range(len(frame)): 
        doc = nlp(frame['Sentence'][i])
        probs.append(doc.cats['Definition'])
    return np.array(probs)

# %%
preds = get_preds(testframe)

# %%
preds = np.array(preds)

# %%
y_test = testframe['HasDef']

# %%
print(pd.DataFrame(metrics.confusion_matrix(y_test, np.round(preds))))
# Out:
#      0    1
# 0  507   73
# 1  128  151

# %%
print(metrics.classification_report(y_test, np.round(preds)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       580
#            1       0.67      0.54      0.60       279
#
#     accuracy                           0.77       859
#    macro avg       0.74      0.71      0.72       859
# weighted avg       0.76      0.77      0.76       859

# %%
print(metrics.precision_score(y_test, np.round(preds)))
# Out:
# 0.6741071428571429

# %%
print(metrics.recall_score(y_test, np.round(preds)))
# Out:
# 0.5412186379928315

# %%
print(metrics.auc(y_test, np.round(preds)))

# %%
def check_acc(frame):
    acc = 0
    frame = frame.reset_index(drop=True)
    for i in range(len(frame)): 
        doc = nlp(frame['Sentence'][i])
        is_def = doc.cats['Definition']
        if is_def > 0.5 and frame['HasDef'][i] == 1: 
            acc += 1
        if is_def <= 0.5 and frame['HasDef'][i] == 0: 
            acc += 1
            
    return acc/len(frame)

# %%
check_acc(testframe)
# Out:
# 0.7566938300349243

# %%
nlp()

# %%
! ls
# Out:
# wiki_bad.txt  wiki_good.txt

# %%
path = 'mars/definition_extraction/wcl_datasets_v1.2/wikipedia/'

# %%
import os

# %%
os.path.join(path, 'wiki_bad.txt')
# Out:
# 'mars/definition_extraction/wcl_datasets_v1.2/wikipedia/wiki_bad.txt'

# %%
files = ('wiki_bad.txt', 'wiki_good.txt')

# %%
path = 'mars/definition_extraction/wcl_datasets_v1.2/wikipedia/'

# %%
files = None

# %%
def create_from_wiki(path = 'mars/definition_extraction/wcl_datasets_v1.2/wikipedia/', files = None):
    
    if files is None: 
        files = {'wiki_bad.txt':0, 'wiki_good.txt':1}

    file_sentences = {} 

    for f in files.keys(): 
        filename = os.path.join(path, f)
        defs = []
        with open(filename, 'rb') as file:
            lines = file.readlines()
            lines = np.array([line.rstrip() for line in lines])

        for line in lines[1::2]:
            defs.append(str(line)[2:].split(':')[0])

        lines = lines[::2]
        for i, line in enumerate(lines): 
            lines[i] = str(line)[4:-2]
        lines = lines.astype(str)

        for i, line in enumerate(lines): 
            lines[i] = lines[i].replace('TARGET', defs[i])

        lines = list(lines)
        lines = [(line, files[f]) for line in lines]

        file_sentences[f] = lines

    file_sentences = list(file_sentences.values())[0] + list(file_sentences.values())[1] 
    return file_sentences

# %%
create_from_wiki()
# Out:
# [('!Hawk has not been seen since Season ', 0),
#  ('Other colonies in West !Marredpally include Indrapuri railway colony, Krishnapuri colony, SarvaSukhi Colony, and Samrat Colony',
#   0),
#  ('The premise of the program revolves around !Tammy Parker, an 18-year-old country girl who moves back and forth between her country family, who lives on a bayou houseboat, and the wealthy Brents, who own a plantation and pancake business',
#   0),
#  ('He also answers to the questions asked from the readers in Hi !Madhan in Anada Vikatan which is very informative',
#   0),
#  ('The correct procedure with this !Malfunction is to deploy the reserve from a stable belly down position',
#   0),
#  ('The !Kufi has no religious significance', 0),
#  ('Sometimes the player must help trapped individuals escape as well, and it will take quick thinking and planning ahead to !Exit the building successfully',
#   0),
#  ('The !Bartians, along with the other Prussians, were conquered by the Teutonic Knights, who Christianized them, brought in newcomers, and built many towns and cities',
#   0),
#  ('The !Dreambox is based on the DBox2 units that were distributed by Kirch Media for its pay-TV services before its bankruptcy; it uses the same Linux-based software originally developed for the DBox2',
#   0),
#  ('!Deliverance released "River Disturbance" in 1994 and "Camelot in Smithereens" in 1995',
#   0),
#  ('Earlier references are found (familysearch.org) of Alvericus de BERNEKOWE born in !Barnekow, Mecklenburg-Schwerin, Germany in about 1186',
#   0),
#  ('Sam Hurt revived !Eyebeam in 1995, but as a weekly', 0),
#  ('Aggregatibacter actinomycetemcomitans is a gram negative $Coccobacillus which is prevalent in subgingival plaques',
#   0),
#  ('Many reviewers stated that, "the graphics, while certainly not PGR3 or Gran Turismo 4 quality, are completely adequate" and "allow !Redline to run on almost any Mac." However, reviewers almost universally disliked the lack of a damage model in the simulation mode',
#   0),
#  ('At national level, !Ballyragget, as part of the Carlow-Kilkenny constituency, is represented by 5 Teachta\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbd D\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdla in D\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdil Eireann',
#   0),
#  ('s 2004 redescription of Nipponosaurus found a close relationship between Nipponosaurus and !Hypacrosaurus stebingeri, indicating that Hypacrosaurus may be paraphyletic, this was rejected in a later, more comprehensive reanalysis of lambeosaurines, which found the two species of Hypacrosaurus to form a clade without Nipponosaurus, with Corythosaurus and Olorotitan being the closest relatives',
#   0),
#  ('It begins : Solomon Waxtend was a shoemaker of !Podunk, a small village of New York some forty years ago',
#   0),
#  ('As of June 2008 they have been signed to Brian "Head" Welch ex-korn guitarist\\\'s new label "Driven Music Group" distributed by Ryko/ Warner Music Group, The groups new album should be out this fall! On July 2008, !Crossbreed opened up their own audio visual recording studio',
#   0),
#  ('"Although the !Electrocoagulation mechanism resembles chemical coagulation in that the cationic species are responsible for the neutralization of surface charges, the characteristics of the electrocoagulated flock differ dramatically from those generated by chemical coagulation. An electrocogulated flock tends to contain less bound water, is more shear resistant and is more readily filterable" - Woytowich D.L',
#   0),
#  ('On one of these missions on 9 August 1969, a UH-1E from !HMLA-367 was shot down near Tchepone, resulting in the loss of Lt',
#   0),
#  ('These observations indicate that !Dysnomia orbits Eris at a distance of 37,370\\xcc\\xad\\xef\\xbf\\xbd150 km',
#   0),
#  ('!Tetraoxygen nevertheless been detected as a short-lived chemical species in mass spectrometry experiments',
#   0),
#  ('!Wyeth India Ltd', 0),
#  ("Although this idea was not fully supported at the time, it was certainly in the air, as shown by William Parks's naming of a nearly complete skeleton from the Dinosaur Park Formation as Kritosaurus incurvimanus, not !Gryposaurus incurvimanus (interestingly, he left Gryposaurus notabilis alone in its own genus)",
#   0),
#  ('!PuzzleCrack 2006 was run from October 16 to October 20, 2006, again by Bert Johnson of Allbase',
#   0),
#  ('The majority of !Hunkpapa Lakota now reside in the Standing Rock Indian Reservation of South and North Dakota',
#   0),
#  ('The cross section of a !Yaodong is similar to that of a cave: a rectangle in the lower part connected to a semi-circle in the upper part',
#   0),
#  ('The merchant loses the goods or services sold, the payment, the fees for processing the payment, any currency conversion commissions, and the !Chargeback penalty',
#   0),
#  ('Gaj, "Polish Cipher Machine - !Lacida," Cryptologia, 16 (1), January 1992, pp',
#   0),
#  (':Note: A Bias may be applied or produced by (i) the electrical characteristics of the line, (ii) the terminal equipment, and (iii) the signaling scheme',
#   0),
#  ('Generally, a !SINPO with a code number starting with a 2 or lower would not be worth reporting, unless you had no noise, interference or loss of propagation, since it would be likely the reception would be unintelligible',
#   0),
#  ('With the !Osteotome technique, osteoplastic procedures have been developed with which the bone quality (compaction of local bone) and bone quantity (ridge extension in horizontal and vertical dimension) are routinely improved and adequate primary stability of the implants can be ensured with a high degree of predictability',
#   0),
#  ('!Nottuln has bus lines that reach out to Coesfeld, Darup, and Roxel with the R62/3; Billerbeck and Appelhuelsen with the T85; and Muenster with the S60',
#   0),
#  ('There are silvery stripes that run the length of the leaves Aplectrum hyemale will spread underground through the growth of its tubers, forming large colonies',
#   0),
#  ('!FOSS.IN is organized by the dedicated efforts of the linux-bangalore team, and is made possible by the contributions of their members',
#   0),
#  ('!Openfiler includes support for volume-based partitioning, Ext3, JFS and XFS as on-disk native filesystems, point-in-time snapshots with scheduling, quota-based resource allocation, and a single unified interface for share management which makes allocating shares for various network file-system protocols easy',
#   0),
#  ('Due to possessing psionic powers, !Looker does not share the vampire weakness to sunlight; however, she presumably requires blood as other vampires do',
#   0),
#  ('As Marc Gascoigne puts it "It became obvious very quickly that the occasional comic strip in !Inferno! along with the short stories was OK, but very soon what we needed to do was a proper comic, so about a year after Inferno! kicked in, Warhammer Monthly made its debut."',
#   0),
#  ("!Rieti has a station on the Terni-L'Aquila railway", 0),
#  ('!Rhymefest was born July 6, 1980 on the south side of Chicago in Jeffrey Manor',
#   0),
#  ('This spectrum was added by the FCC in 2003 to "align the frequency bands used by !U-NII> devices in the United States with bands in other parts of the world"',
#   0),
#  ('The !Psykter would be filled with wine, and then be placed in a krater full of cold water or ice',
#   0),
#  ('The shape of the vessel can be traced in pottery back to the Protogeometric period in Athens, however the Athenian !Pyxis has various different shapes itself',
#   0),
#  ('A double !Reverse adds another level of surprise to the defense; however, the play takes more time and space to develop and increases the risk of a big loss or a fumbled handoff',
#   0),
#  ('The !Hydria has three handles', 0),
#  ('The !Lekythos was used for anointing dead bodies of unmarried men and many lekythoi are found in tombs',
#   0),
#  ('The !Loutrophoros was used to hold water during marriage and funeral rituals, and was placed in the tombs of the unmarried',
#   0),
#  ("Prominent $Occiput is a feature of Trisomy 18 (Edward's Syndrome), along with small jaw, low-set ears, and mental retardation",
#   0),
#  ('Most types of !Alabastron have a narrow body with a rounded end, a narrow neck and a broad, splayed mouth',
#   0),
#  ('!Necrodeath released the album Draculea on October 22, 2007', 0),
#  ('Trees based on rRNA show the $Hartmannellidae as usually defined are paraphyletic to the Amoebidae, which may adopt similar forms',
#   0),
#  ('Traditionally a fishing village, with the construction of the nearby Sullom Voe Oil Terminal in the 1970s !Brae grew rapidly, merging with the nearby village of Northbrae',
#   0),
#  ("After unwittingly releasing the Darkwatch's greatest enemy, a vampire lord named Lazarus Malkoth, Jericho is conscripted into the !Darkwatch as an elite operative",
#   0),
#  ('He may also be named after !Johnny Cash as both are "cowboys" who are known to dress in black',
#   0),
#  ('Patients with scleroderma, a disease that thickens and hardens the skin, sometimes require oral !Commissurotomy to open the corners of the mouth, the commissures, to allow dental treatment',
#   0),
#  ('" and also that it would be speaking to the police about the group. The Welcome to Lancashire signs were erected on the boundaries with Blackburn with Darwen and Blackpool unitary authorities by the county council in 2004 to show where its services begin. !CountyWatch responded stating that, "The sign says \\\'Welcome to Lancashire\\\', it doesn\\\'t say \\\'Welcome to the administrative unit of Lancashire County Council - that would be all right',
#   0),
#  ('According to the root zone file, the single !root entry was replaced in 2006 with just vrsn-end-of-zone-marker-dummy-record, to be reintroduced later in 2006 in its original form',
#   0),
#  ('DEFAULTSORT:!Amateur    comedy-drama-film-stub crime-film-stub ', 0),
#  ('April 1991 anl\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdsslich der Ausstellung Euphronios, der Maler',
#   0),
#  ('Prior to the opening of the Trafficway, !K-10 had ended at the junction of US-40 and US-59 in Lawrence',
#   0),
#  ('These claims would have been validated by the !.asia validation partner (there were two including Deloitte Touche) and where multiple applications were received, the domains would go to auction',
#   0),
#  ('For advertising purposes, they were called the Hellions, but this name was never used by either !Emplate or his followers',
#   0),
#  ('The !Pangal are mainly concentrated in and around Imphal, the capital of Manipur',
#   0),
#  ('A !Pendent most often requires one or more of the same as itself to completely function',
#   0),
#  ('!Knightmare series   ', 0),
#  ('A variation of the chicken !Parmigiana, known locally as the "Parmo", can be found in the North East of England',
#   0),
#  ('A few differences to the finished product were: at start up, cars were already on the !Freeway instead of all being lined up on the right side; the score and Activision logo were yellow instead of pink; instead of controlling a chicken, the player controlled a man and instead of being forced down a bit when hit by a car, the character would turn into a glowing streak of blood; there were some minor differences in the sounds used; and pressing the fire button reset the game',
#   0),
#  ('"It was really quite amazing. We\\\'d opened a tour with the Moody Blues ... we were expecting offers of work to arrive, but no one asked us to do anything. The next !Hotlegs records flopped and we didn\\\'t get a single offer of work. It was extraordinary. We\\\'d had a hit record that had sold two million copies and nobody wanted us." and "Desperate Dan", Germany and Spain), but none charted. In 1976 Stewart, by then achieving success with 10cc, +admitted: "\\\'Lady Sadie\\\' had no class and no originality. It was a very mediocre pop song." The album also presented a problem, he said: "That was so different to \\\'Neanderthal Man\\\' that it was totally alien to what people were expecting from us. It was a good record, a little ahead of its time. It was similar to the things we are doing now. It was very melodic with chord structures that hadn\\\'t been used before !\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd and some of the sounds that we used on that album hadn\\\'t been heard at the time."',
#   0),
#  ('!Protonema are characteristic of all mosses and some liverworts but are absent from hornworts',
#   0),
#  ('Steel monocoque construction is now the most common form of car !Bodywork, although aluminium and carbon fibre may also be used',
#   0),
#  ('Currently Incharge of all northern Region airport Is a !Chaturvedi Mr M.N Chaturvedi,His one of the lucky person who got the opportunity to Present india in ICAO(UN Body)',
#   0),
#  ('The unique feature of !Ning is that anyone can create their own custom social network for a particular topic or need, catering to specific audiences',
#   0),
#  ('The many unusual features of these plants led to the establishment in 1958 of the species !Takakia lepidozioides, in a new genus Takakia, named to honor the man who rediscovered it and recognized its unique characteristics',
#   0),
#  ('Trade Me Limited owns several sites which appear grouped together as tabs at the top of the !TradeMe website (see top of page), allowing navigation between the related pages',
#   0),
#  ('The !Boomershoot has appeared in magazines such as Newsweek and Outside Magazine, KING 5 Evening Magazine as well as numerous articles in local newspapers',
#   0),
#  ("Nonetheless, she does not revert to her !Althena form when her memories and powers are released, and though 'Lucia' is eventually killed, Althena assumes the form of Lucia again soon after",
#   0),
#  ('$Kollengode is home to Late Mr.C.Vasudevan Menon (MLA), who was an old Marxist leader and Secretary of Marxist supported Farm Workers union',
#   0),
#  ('!NYCO is led by Ted Atkatz, a former principal percussionist for the Chicago Symphony Orchestra',
#   0),
#  ('The !Z\\xcc\\xb0\\xef\\xbf\\xbdzere runs through the town Manteigas,passes south of the city Covilh\\xcc\\xb0\\xef\\xbf\\xbd and esat of the town of Pedrog\\xcc\\xb0\\xef\\xbf\\xbdo Grande',
#   0),
#  ('Homes usually have a !Setback from the property boundary, so that they cannot be placed too close together',
#   0),
#  ('An example of !Muniment of Title would include but is not limited to using a death certificate of a joint tenant to prove that title resides with living joint tenant',
#   0),
#  ('In first edition supplements, !Glasya was very influential but not very powerful in combat and thus preferred to stay on the sidelines when it came to battle',
#   0),
#  ('Unlike the androgynous Taelons with whom they share a biological ancestor, the !Jaridians have two sexes, with both males and females engaging in combat',
#   0),
#  ('Archetype was the official seal of !Weilburg from the year 1329', 0),
#  ('Though the name can be found written alternatively as Jharna, !Zarana is the most common spelling',
#   0),
#  ('In between adjacent !Haustra are semi-lunar folds, known as the plicae semilunares',
#   0),
#  ('It is bent forward at the summit so as to present a prominent lip which is received into the !Olecranon fossa of the humerus in extension of the forearm',
#   0),
#  ('Thomas Kleine, German footballer, was born in !Wermelskirchen in 1977', 0),
#  ('Most Synarthrosis joints are fibrous', 0),
#  ('It has a similar temperate climate, although it is said that it rains every day in !Albion (an exaggeration of the common perception of the British and Irish climate)',
#   0),
#  ('For elections to Penwith Council !Morvah falls within the Morvah, Pendeen and St Just ward',
#   0),
#  ('Presidential candidate Jean-Marie Le Pen told residents of Argenteuil, many of them immigrants, "If some want to Karcherize you, to exclude you, we want to help you get out of these ghettos." As a response, !K\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdrcher France sent a letter to all of the candidates in the 2007 presidential election asking them not to use the company\\\'s name this way, and has run ads in newspapers disassociating itself from the remarks',
#   0),
#  ('Molarity and !Osmolarity are not commonly used in osmometry because they are temperature dependent; that is, water changes its volume with temperature',
#   0),
#  ('Eventually, !KZON switched to a Rhythmic CHR format', 0),
#  ('The !Betrayal is deepened because Jerry, we learn, was best man at their wedding',
#   0),
#  ('!Gemsbok live in herds of about 10-40 animals, which consist of a dominant male, a few non-dominant males, and females',
#   0),
#  ('The United States Congress authorized the creation of !UPIN IDs through Section 9202 of the Consolidated Omnibus Budget Reconciliation Act of 1985',
#   0),
#  ('The !Tether strap is located on the rear of the child car safety seat and has a hook',
#   0),
#  ('Another form of !Gibberish known as allibi is spoken using the insertion -allib-',
#   0),
#  ('!Cushman scooters usually weighed about 250 to 335 pounds and some had as much as 9 horsepower',
#   0),
#  ('!Mondo was given the task of sneaking in through the ground and finding Illyana',
#   0),
#  ('!Postvention includes procedures to alleviate the distress of suicidally bereaved individuals, reduce the risk of imitative suicidal behavior, and promote the healthy recovery of the affected community',
#   0),
#  ('The town of !Fo\\xcc\\xb0\\xef\\xbf\\xbda is situated at about convert north by northwest of \\xcc\\xb3\\xef\\xbf\\xbdzmir city center',
#   0),
#  ('Certain researchers consider the decline in the !Chinkara population as the reason behind the extinction of the Asiatic Cheetah in India',
#   0),
#  ('!Surdo sizes normally vary between 16" or even 14" and 26" or even 29" diameter',
#   0),
#  ('Usually the !Udu is made of clay', 0),
#  ('Invented by Bill Bernardi (and co-engineered by Roger Noble and with former !Lyricon performer Chuck Greenberg), it was manufactured by a company called Computone Inc in Massachusetts',
#   0),
#  ('Often it is in the operations area rather than the process area that !Muda can be eliminated and remove the blockage to the plan',
#   0),
#  ('In 1973 a group of New Yorkers who later renamed themselves Infinity Broadcasting acquired !KOME as the first of many stations to come',
#   0),
#  ('One might !Waffle throughout an essay or a presentation, when not having enough material or needing to fill in time',
#   0),
#  ("!Palatschinken are traditionally filled with apricot jam, rolled and sprinkled with some confectioner's sugar, but a variety of different fruit jams, chocolate sauce, nuts, dried or fresh fruit (banana slices etc), quark, poppy seed, or any combination thereof, are often used",
#   0),
#  ('The District Head Quarter Janjgir of the district !Janjgir-Champa is the city of Maharaja Jaajawalya Dev of Kulchury dynasty',
#   0),
#  ('!Kaufungen is situated on the M\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdrchenlandweg (literally: fairy tale way), a long distance footpath and riding and cycle way',
#   0),
#  ('!Gaylussacia frondosa is found in the eastern United States', 0),
#  ("The mining developments around !Botallack form part of the St Just mining district's successful inclusion in the Cornwall and West Devon Mining Landscape World Heritage site which was approved in July 2006",
#   0),
#  ('!Agropoli has also a large tourist port, connected by ferries to Capri, Ischia and Naples',
#   0),
#  ('The compression form used by a !JT file is related to the JT file format version in which it was written',
#   0),
#  ('They are known as Sicangu Oyate, or "Burnt Thighs Nation," and so, were called !Brul\\xcc\\xb0\\xef\\xbf\\xbd (lit. "burnt") by the French',
#   0),
#  ('A variant of the DNA sequence at a given !Locus is called an allele', 0),
#  ('American forces within a !Kaserne could range anywhere from company size, with a few hundred troops and equipment, to brigade level formation with supporting units, or approximately three to five thousand troops and their equipment',
#   0),
#  ('Adding the protective !Catshead to the gable end of an existing roofline made roofing tasks simpler, and conserved building supplies by eliminating the flashing that would be required by a completely separate roof',
#   0),
#  ('Its territory, which was smaller than that of present !Csongr\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdd county, is presently in southern Hungary and northern Serbia',
#   0),
#  ('The primary focus of $Theodism is an attempt to reconstruct the pre-Christian religion of the Germanic branch of the Indo-European peoples, within the cultural framework and community environment of specific tribes',
#   0),
#  ('A 4th century inscription tells of two ladies who had purchased for their future interment, a !Bisomus in a "new crypt" which contained the body of a Saint: :IN CRYPTA NOBA RETRO SAN :CTUS EMERVM VIVAS BALER :RA ET SABINA MERUM LOC :V BISOM AB APRONE ET A :BIATORE Like so many pious but rather superstitious persons of that age, "Balerra" and "Sabina" wished to be buried in the closest proximity to a martyr, retro sanctos, a privilege which, as we learn from another inscription, "many desire but few receive" (quod multi cupiunt et rari accipiunt)',
#   0),
#  ('!Egeus is very insistent that his daughter marry Demetrius, despite her own feelings',
#   0),
#  ('The !Thran Empire, centered in their capital city of Halcyon, encompassed much of the main planet of the plane of Dominaria',
#   0),
#  ('The following are links to pictures of !Myddfai taken by the club', 0),
#  ('The !Holomorph provides interesting examples of groups, and allows one to treat group elements and group automorphism in a uniform context',
#   0),
#  ('!Campion leads two young men, one American and one British, on a midnight raid on a hideout, led by Lugg and one of his reformed criminal friends',
#   0),
#  ('The !Pencilina is played by striking its strings and bells with sticks', 0),
#  ('On January 18, 2006 the Sacramento Bee included !HumorFeed in a timeline of notable satire publications and shows ranging from the founding of Mad Magazine in 1952 to the debut of the Colbert Report',
#   0),
#  ("The !Senepol breed combines the N'Dama characteristics of heat tolerance and insect resistance with the extreme gentleness, good meat, and high milk production of the Red Poll",
#   0),
#  ('!Paste became a monthly with its August 2006 issue', 0),
#  ("!Newdigate has a medieval Church called St Peter's, an infant school, a village shop, run and owned by Bob Bettesworth, with sub post office and two public houses as well as many small businesses",
#   0),
#  ('The later the !Cutoff the higher the steam pressure will be on average along the stroke of the piston delivering more force to the piston but, since there will still be unexploited pressure in the cylinder at the end of the stroke, this is achieved at the expense of engine efficiency',
#   0),
#  ("This child is !Clig\\xcc\\xb0\\xef\\xbf\\xbds, who is raised in Greece but follows his father's footsteps to Arthur's kingdom when he is old enough to be knighted",
#   0),
#  ('Many mushrooms in the genus - for example !Cortinarius sanguineus and other species in section Dermocybe - are beautiful and colourful and are often used for dyeing',
#   0),
#  ('Typical symptoms of a !Strain include localized pain, stiffness, inflammation, and bruising around the strained muscle',
#   0),
#  ('There are also generic versions of !Dacarbazine available from APP, Bedford, Mayne Pharma and Sicor (Teva)',
#   0),
#  ('!Smbmount is identical in functionality as using mount -t smbfs', 0),
#  ('In a reference to this, just before !Jak speaks for the first time in Jak II, Daxter pleads with him to "Say something! Just this once!"',
#   0),
#  ('!SunCom Wireless only operates on the GSM platform now', 0),
#  ('!KALC came on the air with a hot adult contemporary format, branded as "Alice 106"',
#   0),
#  ('!Coldfront also hosts a number of related third party channels, including clan, guild, society, corporation and amateur radio channels',
#   0),
#  ('The campaign was brought back in 2001 when !Luvs began using the cloth-like cover, this time placing the water balloon on diaper on cotton balls',
#   0),
#  ('!Gnash is released under the GNU General Public License', 0),
#  ('The SS-N-23 was designed for use by the Russian Delta IV submarine, each of which is capable of carrying 16 missiles',
#   0),
#  ('His death is deeply mourned by !Alleycats fans as seen in the press and media',
#   0),
#  ('The story of !Gora Badal has been depicted on a wall painting in Eklingaji temple in Udaipur',
#   0),
#  ('In !Mahasamund, 14% of the population is under 6 years of age', 0),
#  ('Nitronium is a more potent electrophile than is !Nitrosonium, as anticipated by the fact that the former is derived from a strong acid (nitric acid) and the latter from a weak acid (nitrous acid)',
#   0),
#  ('A sequel named !Rollcage Stage II was released in 2000 for Windows and Playstation',
#   0),
#  ('Covering the head is respectful in Sikhism and if a man is not wearing a turban, then a !Rum\\xcc\\xb3\\xef\\xbf\\xbdl must be worn before entering the Gurdwara',
#   0),
#  ('Although the !Rhomphaia was similar to the Falx, most archaeological evidence suggests that rhomphaias were forged with straight or slightly curved blades, presumably to enable their use as both a thrusting and slashing weapon',
#   0),
#  ('A !Meadery would typically be in the style of a banquet hall, having wooden flooring, heavy wooden tables, and lit by candlelight with white-painted granite walls',
#   0),
#  ('The city also hosts the annual Chuncheon !Makguksu Noodle Festival, featuring makguksu tastings and other celebrations',
#   0),
#  ('After several albums, many no.1 hits and two years of sheer success, !Hi-5 came to an end in 2005',
#   0),
#  ('By 1968, !WLS-FM expanded its hours on the air from 6 a.m', 0),
#  ('The !CERNET project is funded by the Chinese government and directly managed by the Chinese Ministry of Education',
#   0),
#  ('He can Armor Fuse with !Daigunder to form Legendary Battle Warrior !DragoDaigunder (Dragon Daigunder) with DragoFlame as a sword and DragoFreezer as a shield and attacks with his Burst Cannon',
#   0),
#  ('!KTCL helped break local bands The Fray, Meese, 3OH!3, Single File, Tickle Me Pink, and Flobots onto the national scene',
#   0),
#  ('!Azumi (played by Aya Ueto) is discovered as a 7\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd8 year old girl kneeling without visible emotion next to the body of her dead mother by the samurai master Gessai, played by Yoshio Harada, and his entourage of young students',
#   0),
#  ('However, !Arabella goes upstairs and Mandryka, grieving and blaming himself, stays downstairs',
#   0),
#  ('The Bicorne or Bycorne, a counterpart to the !Chichevache which fed on obedient and kind husbands, was reputedly fat and plump because of the plentiful supply of such men',
#   0),
#  ('In battle, the !Reiksguard favour fighting in large regiments, the better to defeat the enemy with the full splendor of their mirrored armor and crimson plumes',
#   0),
#  ("!Cai is romanized as Cai in the People's Republic of China, Tsai (or occasionally Tsay or Chai) in the Republic of China (Taiwan), and Choi or Choy in Hong Kong",
#   0),
#  ('It has been suggested that !RLI in lower eukaryotes functions by inhibiting RNAses involved in ribosomal biosynthesis, thereby regulating the process',
#   0),
#  ('At that time, !Trap-Jaw is knocked into the room by Orko wielding the Power Sword',
#   0),
#  ('It is a paramount feature of existentialist philosophy, in which !Anguish is often understood as the experience of an utterly free being in a world with zero absolutes (existential despair)',
#   0),
#  ('Anthony Lynch, a native of !Ballyvourney and a player on the local football team also plays for the Cork Senior Football team',
#   0),
#  ('In February 1998, !Sky signed a major-label record deal with EMI Music Canada',
#   0),
#  ("!Tarmvred recorded much of Viva 6581 using a MOS 6581 sound chip, featured in early-80's computers such as the Commodore 64",
#   0),
#  ('During Dominican Parades you will find the streets littered with !Brugal bottles and Banana Peels',
#   0),
#  ('Only the !Brain survived, and Caulder planned on putting his brain in a robot body',
#   0),
#  ('A hole is bored in one or both of the objects and the !Dowel is inserted into the hole',
#   0),
#  ('An !Armlock that hyperflexes or hyperrotates the shoulder joint is referred to as a shoulder lock, and an armlock that hyperextends the elbow joint is called an armbar',
#   0),
#  ('Famous Moroccan writer Tahar Ben Jelloun has written This Blinding Absence of Light, based on the experiences of one !Tazmamart prisoner',
#   0),
#  ('!Kamsa was told in a prophecy that the eighth son of Devaki would kill him, so he imprisoned both Devaki and her husband, Vasudeva and allowed them to live only under the condition that all their children would be handed over to him, as soon as they were born',
#   0),
#  ('While the contours of the !Makhzen are vague, the government itself is not part of it, on the contrary Makhzen often acts as a shadow government which only reports to the king, bypassing the prime minister',
#   0),
#  ('The $Adventure was described as a "Dungeon Masters Kit" rather than a "module" or an "adventure." Also in 1976, the adventure Lost Caverns of Tsojconth was distributed by Metro Detroit Gamers as the tournament module for the gaming convention Wintercon V, but was not published for general distribution at the time',
#   0),
#  ('The three square faces of the !Tetrahemihexahedron are, like the three facial orientations of the cube, mutually perpendicular',
#   0),
#  ('His best known role is as the straight man in the comedic duo "!Viruta y Capulina"',
#   0),
#  ('The !Vesle rises at an altitude of about 187 metres, on the dip slope of the Upper Cretaceous chalk, near the village of Somme-Vesle, east of Ch\\xcc\\xb0\\xef\\xbf\\xbdlons-en-Champagne',
#   0),
#  ('A collection of recipes collected by !Curnonsky from restaurants', 0),
#  ('Unlike the MAC-10, the !BXP has an ambidextrous safety lever and a separate fire mode selector built into the trigger',
#   0),
#  ('!Historicism became a significant feature in the Protestant-Catholic conflicts of the Reformation',
#   0),
#  ('!Protothreads function as stackless, lightweight threads providing a blocking context cheaply using only two bytes per protothread',
#   0),
#  ('He worked as a !Supernumerary officer in 1761', 0),
#  ('!WalkSAT and GSAT differ in the methods used to select the variable to flip',
#   0),
#  ('He had the same to say about Shalini, who was also in a relationship with another actor Ajit, during the period !Alaipayuthey was being shot, and got married to him after the movie',
#   0),
#  ('A coach bolt (see carriage bolt) is fitted through the middle and adjusted so that the !Gripe will fit onto the land (the joint between the adjacent strakes) while admitting the point of a wedge between the free ends of the two parts of the gripe',
#   0),
#  ('The people who work in the !Foundry making molds and pouring castings traditionally worked moving sand extensively, and thus were affectionately called sandrats',
#   0),
#  ('The album sleeve shows the members of the band dressed up as !10 of the most powerful world leaders of the time (L-R Yasser Arafat, Rajiv Gandhi, Pope John Paul II, Mikhael Gorbachev, Margaret Thatcher, George H. W. Bush, Fidel Castro, Muammar al-Gaddafi, Benazir Bhutto, Joshua Nkomo) Despite the album\\\'s American-friendly sound and the moderate success of "Sweet Smell of Success" in America (reaching #5 on the Modern Rock Chart), it failed to chart their and the band were not given an American tour',
#   0),
#  ('The band was never particularly successful in the United States, although !Family did achieve recognition in the United Kingdom, appearing at several festivals',
#   0),
#  ('Akbars policy of pacification and reconciliation had its desired effect and we find the !Gakhars leading a peaceful and uneventful life during the major part of the Mughal rule',
#   0),
#  ('The !Dark\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbdMatter Arms and Equipment Guide provided a more detailed list of equipment appropriate to the setting',
#   0),
#  ('When a pipe is broken, the process writing to it is sent the !SIGPIPE signal',
#   0),
#  ('In order to protect these species, the !Outeniqua Nature Reserve was established',
#   0),
#  ('Matt Cale, a reviewer for Ruthlessreviews.com, said: "Based on my initial, purely gut reaction, !Onibaba is a visual masterpiece, but also the sort of story that contains layer after layer of insight. I wouldn\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbdt argue that I understood everything after one viewing, but I\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbdm so intrigued that I want to read more reviews, scan a few clips, and even revisit the film in its entirety. It\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbds the sort of film made for contemplation; so mysterious and so blissfully unconcerned with immediate gratification that I have no doubt it will begin the slow climb up the list of films near and dear to my heart." Members of Variety opened their review with: "Raw fare is sometimes high adventure and exciting, at other times dull in its so-called symbolism. Too often, it turns out to be a pot-pourri of ravenous eating and blatant sex", referring to the films violence and sexual overtones',
#   0),
#  ('More recently, !Murukku has become available in North America, and is made by several manufacturers in the United States',
#   0),
#  ('!XL will not require a virtual machine to run', 0),
#  ('A 2007 article for the Scottsdale Times in Arizona covered similar ground including the issues of !Neuticles, lavish spending on posh pet wardrobes, heated dog bowls and other creature comforts',
#   0),
#  ('A horticulturist may be a plantsman, but a !Plantsman is not necessarily a horticulturist',
#   0),
#  ('He befriends the main character, an urchin named Thomas and reveals that he is a messenger from God (called Riathamus here), and that Demurral is a !Shadowmancer, a sorcerer who can control the dead',
#   0),
#  ("On the Castello map (1660, illustration) !Whitehall, with its white roof, stands on a jutting piece of land at Manhattan's tip, facing along the waterfront strand that extends along the East River",
#   0),
#  ('It shares the goals of the other !Reprieve organizations', 0),
#  ('In 1976 Bolan and !T.Rex released their penultimate album, Futuristic Dragon, which was better received, with a schizophrenic production style veering from Wall of Sound style songs to nostalgic nods to the old T.Rex boogie machine, but still only managed to reach #50',
#   0),
#  ('Otto Sverdrup\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbds fourth and last expedition in Arctic Siberian waters was in 1921, when, from the bridge of the Soviet Icebreaker !Lenin, he commanded a convoy of five cargo ships on an experimental run through the Kara Sea to the mouths of the Ob and Yenisei',
#   0),
#  ("On the 14th December 2007, in association with Jo Whiley and her BBC Radio 1 Live Lounge Tour, the Stereophonics returned back to their home village of !Cwmaman to play an exclusive acoustic gig in the Cwmaman Working Men's Club, the venue where the band first performed",
#   0),
#  ('!Buddha   ', 0),
#  ('!CarMax (NYSE: KMX) reported sharply lower first quarter earnings of 13 cents per share compared with 30 cents per share last year prompting the used car retailer to suspend its full year earnings and sales guidance',
#   0),
#  (', In October 24, 2005, the !AutoNation building in downtown Fort Lauderdale suffered significant damage due to Hurricane Wilma',
#   0),
#  ('It can also refer to a specialised firm such as a !Boutique investment bank or boutique law firm',
#   0),
#  ('In 1972, when the segmenting of bavarian districts was reformed, the district of !Tirschenreuth was expanded with the former district of Kemnath',
#   0),
#  ('Drax, a character bearing a "Z" symbol similar to Superman\\\'s "S" who mentions his parents throughout the episode (leading to speculation that Zod and !Ursa are Drax\\\'s parents)',
#   0),
#  ('Megatron decimated the Terrorcon invasion, and !Thrust attempted to ingratiate himself with his bemused former leader',
#   0),
#  ('The key difference is that The !Carver offered his victims no choice; he both cut and raped them',
#   0),
#  ("Freeing a !W'rkncacnter is possible, but very difficult (given the nature of their prisons)",
#   0),
#  ('At the early roots of !Pedology as a separate study was G. Stanley Hall, who was also instrumental in the development of modern educational psychology',
#   0),
#  ('In the mid-1980s !MarkAir and Alaska Airlines entered into a codesharing agreement with MarkAir operating as Alaska Airlines to the communites of Dillingham, Dutch Harbor, Barrow, Aniak, St. Mary\\\'s and Alaska Airlines feeding MarkAir from its routes from Seattle and other "lower 48" destinations',
#   0),
#  ('The !Giralda has no stairs; instead, 34 ramps are used to ascend the tower',
#   0),
#  ('The Northern !Kamilaroi people have a strong cultural connection with the Bigambul People and the tribes met regularly for joint ceremonies at Boobera Lagoon near the present day town of Goondiwindi',
#   0),
#  ('The retail ADSL offering from its own Internet service provider (ISP), Xtra, is now more commonly referred to by the company as Xtra Broadband, though the !JetStream brand is still in use',
#   0),
#  ('!Eurofor was formed in 1995, and was answerable to the Western European Union (WEU) directly',
#   0),
#  ('Logical thinking, strategy and tactical problem solving are part of the !XOR experience',
#   0),
#  ("Liebeswalzer (1985) # Psycho # Berliner Fr\\xcc\\xb0\\xef\\xbf\\xbdhling (Berlin Spring) # Die Ferne (The Distance or Far Away) # Die alten M\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdnner (The Old Men) # Am Sonntag (On Sundays) # !Liebeswalzer (f\\xcc\\xb0\\xef\\xbf\\xbdr H.F.) (Waltz of Love (dedicated to H.F.)) # Nester der Nacht (Nests of the Nght) # So 'ne kleine Frau (Such a Little Woman) # Gro\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbder Tr\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdumer (Big Dreamer)  Liebeswalzer (1990 re-release) Tracks 10 - 12 taken from the unreleased original album Zwischen unbefahr'nen Gleisen and never released before",
#   0),
#  ('Some !Linklog software, like Linkwalla, can also be for creating a conventional blog',
#   0),
#  ('Opening in this involucrum allow debris and exudates (including pus) to pass from the !Sequestrum via sinus tracts to the skin',
#   0),
#  ('!AudioTron can stream digital music files from personal computers or NAS devices without the need to install server software on these storage devices since the Audiotron is based on Windows CE and is therefore a computer that looks like audio hardware',
#   0),
#  ('In Urdu it is associated with the moon (aks-e-$Maha - "Shadow of moon")',
#   0),
#  ("About 75,000 motor vehicles and a large number cyclists, mopeds and pedestrians use the tunnel daily, making the !Maastunnel an important part of Rotterdam's road network",
#   0),
#  ('COC boardmembers from 1995 formed the board of Hoezo/!Expreszo and COC Netherlands started funding the magazine from 1995 until 2001',
#   0),
#  ('Here, the !Fouling rate decreases with time, until it finally reaches zero',
#   0),
#  ('$Zima directly means "winter" in Croatian, Bosnian, Polish, Czech, Macedonian, Serbian, Slovak, and Slovene and in transliteration from Bulgarian, Belarusian and Russian languages; the name is also reminiscent of zymurgy, the science of fermentation, or brew-making',
#   0),
#  ("Accepting the offer, !Washout underwent a process that enhanced his mutant ability to the point where Washout had the ability to transform his body into water, project high pressure jets of water from his arms, shape the water into any form, and even manipulate or siphon off the water within another person's body",
#   0),
#  ('The channels cater to a wide variety of program genres, including game shows, news, serials, live TV chat, music video shows and reality shows.$Asianet is the leading television network in malayalam, taking 60% of total viewership',
#   0),
#  ('The !Aduatuci sent troops to assist the Nervii or Nervians in the Battle of the Sabis, and were later defeated by the Romans after withdrawing to a fortified Aduatuci city',
#   0),
#  ('Since the !Tharavadu had a name of its own, it invested the members with a sense of responsibility to conduct themselves in a manner befitting the traditions',
#   0),
#  ('!Gresford church as it stands now dates to 1492 and is a large and very well-built building considering the size of what the population would have been in the present day boundaries of the parish',
#   0),
#  ('If the !Axolemma is damaged, it becomes unable to perform its vital role of maintaining the concentration gradient of ions on the outside of the cell',
#   0),
#  ('In humans, a mutation within the AnkB gene results in the long QT syndrome and sudden death, strengthening the evidence for a role for the !Spectrin cytoskeleton in excitable tissue',
#   0),
#  ('The !Majorization partial order on finite sets can be generalized to the Lorenz ordering, a partial order on distribution functions',
#   0),
#  ('!Click was released in North America on June 23, 2006 by both Columbia Pictures and Revolution Studios',
#   0),
#  ('Over time, the $Buttery became a general food storeroom, and in particular the larders of Oxbridge colleges where students would purchase food and drink',
#   0),
#  ('As the teaching of Latin at the secondary school level declines in the Commonwealth, the practice of !Quis-ego may disappear, although it was still widespread in the late 1980s and early 1990s in schools where Latin was part of the curriculum, and use in the 21st Century has been recorded',
#   0),
#  ('In 1960 however, the district of Sargodha was created and $Shahpur became one of its Tehsils During their rule the British had a regular census of their Indian empire, recording amongst other things religion and caste, the following table lists the percentage of the population belonging to each faith',
#   0),
#  ('Image:Historia-\\xcc\\xb0\\xef\\xbf\\xbdrbol-del-Tule-Oaxaca-Mexico.jpg|!Signboard at Santa Mar\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbda del Tule, Oaxaca, Mexico',
#   0),
#  ('Tigern\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdn Ua Ruairc had three children, Melaghlin (d.1162), Aed, described as crown prince of Breifne, killed by the Anglo-Normans (d.1171) and Dowchawley (d.1171), wife to Ruaidri Ua Conchobair, high king of Ireland, but whether or not !Derbforgaill was their mother is less certain',
#   0),
#  ('Hitler was at the !Felsennest in the autumn of 1939, because there were plans to invade France and the Low Countries',
#   0),
#  ('Other historical characters named !Jesus include Jesus ben Ananias and Jesus ben Sirach',
#   0),
#  ('The size of a !Washitsu is measured by the number of tatami mats, using the counter word j\\xcc\\xb7\\xef\\xbf\\xbd\\xef\\xbf\\xbd (\\xcc\\xa4\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd)',
#   0),
#  ('!Demonax was born c', 0),
#  ('The first season recounts the early adventures of Kryptonian Clark Kent as he adjusts to life in the fictional town of !Smallville, Kansas, during his teenage years before he becomes Superman',
#   0),
#  ('Visconti\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbds meticulous realism gives a bright picture of court life in the nineteenth-century Bavaria and shows with impressive dramatic pathos how a dreamy romantic idealist as !Ludwig succumbs to the strenuous and urgent demands of his responsibilities as king',
#   0),
#  ('In the case of !Cahors, this happened in 1883-1885', 0),
#  ('The gang gained some international prominence in early 2005, when it was revealed that the Urayasu-based cleaning company contracted to Tokyo Disney Resort was run by a member of the !Matsuba-kai, Saburo Shiga (\\xcc\\xb4\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xcc\\xac\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd \\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xcc\\xa9\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd)',
#   0),
#  ('This changed in August 2005, when in a surprise move, the !Kokusui-kai withdrew from the Kant\\xcc\\xb7\\xef\\xbf\\xbd\\xef\\xbf\\xbd alliance and became an affiliate of the Yamaguchi-gumi',
#   0),
#  ('The primary difference between the Filipino version and other versions of the weapon is that the !Tabak-Toyok tends to have shorter handles as well as a longer chain',
#   0),
#  ('A high !Mount can be used to pin one of the opponents arms under the knee, so as to prevent him or her from defending effectively',
#   0),
#  ('At the end of the year, BMW revoked the use of their engines due to the bad PR the team and its owner generated, and Schmidt folded the !ATS team as well as leaving the ATS company',
#   0),
#  ('Code for the !Shrak monster itself was a bit tricky', 0),
#  ('There is also a lesser known male version of !Egg, called MensEGG', 0),
#  ('!Mirrorball is available as an "extra" on the DVD edition of Absolutely Fabulous series 4',
#   0),
#  ('$Posadis is part of a suite which includes graphical configuration and zone file management programs',
#   0),
#  ('The !Bulava design is based on the SS-27 (Topol M), but is both lighter and more sophisticated',
#   0),
#  ('!Makimono were taken to scenic places to enjoy them in a beautiful surrounding, and stored away when home',
#   0),
#  ('The Gaindhu, Gaindha, Gaindhal and !Gandhar gotras are also found amongst the Muslim Jats of Punjab (Pakistan)',
#   0),
#  ('The species !Oxymitra paleacea Bisch', 0),
#  ('!Ardingly station was opened 1 october 1864 by LBSCR', 0),
#  ('The !M32R has been used in Engine Control Units, digital cameras, PDAs', 0),
#  ('We hear no more about the !Chali as such in history, but their name can probably be connected with the Chalusus river (ibid.), tentatively identified as the Trave',
#   0),
#  ('Interestingly (as the above lists mentioned), !Hero airs programs which Animax also airs in some of its channels outside Southeast Asia, e.g',
#   0),
#  ('Lead Highlander: The Series actor Adrian Paul explains, "The !Quickening is the receiving of all the power and knowledge another immortal has obtained throughout his/her life. It is like the receiving of a sacrament or a massive orgasm." The producers describe it so: "The power of the Quickening is the equivalent to a major electrical storm hitting -- windows explode, lights short circuit, it is almost as if the victorious Immortal is in the center of a lightning storm." This energy is absorbed by the Immortal who did the beheading',
#   0),
#  ("In 1985, the !Ichiwa-kai faction sent a team of hitmen to assassinate Takenaka at his mistress's home in Suita, Osaka",
#   0),
#  ("The !Ma'abarot were meant to provide accommodation for the large influx of new !Olim (Jewish immigrants) arriving in the newly independent state of Israel",
#   0),
#  ('Throughout the series, !Falcomon gains the ability to Digivolve into a number of more powerful forms, each with a different name and special attack',
#   0),
#  ('It looked as if !Fandango would be disbanding, and not by choice', 0),
#  ('!Dump can back up a file system to a tape or another disk', 0),
#  ('!Kumbanad has been included as one of the new stations in the draft plan for the Tiruvalla - Sabarimala railway line',
#   0),
#  ('A Free Scholar could not be accredited as a !Provost until he had studied under a registered Master for seven years (though this time requirement was occasionally shortened)',
#   0),
#  ("After 1953, there was competition to the !Trans-Oceanic from both Hallicrafters, with their 'Trans-World' series sets, and RCA, with their 'Strato-World' models",
#   0),
#  ('New information on the skull of !Zuniceratops christopheri, a neoceratopsian dinosaur from the Cretaceous Moreno Hill Formation, New Mexico',
#   0),
#  ('The !Ur-grue character in Beyond Zork may be a reference to Brian Moriarty himself, the creator of the game, who is notably absent from the game\\\'s portrayal of an "Implementors\\\' Luncheon", where each Implementor is recognizably based on a member of the Infocom staff',
#   0),
#  ('!Penybont Road connects the Cwm Tillery area with the town of Abertillery',
#   0),
#  ('!Cubeb is mentioned in alchemical writings by its Arabic name', 0),
# ...
#  ('In !Yelahanka, 11% of the population is under 6 years of age', 0),
#  ('Our texts say nothing as to what were the elements of the prayer of !Terce, Sext, or None before the fourth century',
#   0),
#  ('!Tomica later on also produced models with Disney characters on them and they even started an utterly new series called Putica for these Disney characters',
#   0),
#  ('In August 2006, !HMLA-167 departed MCAS New River after only 5 months at home to join MAG-16 in Al Asad, Iraq',
#   0),
#  ('!D\\xcc\\xb7\\xef\\xbf\\xbd\\xef\\xbf\\xbd-maru were constructed from small scales of leather or metal laced into plates with cord and lacquered',
#   0),
#  ("The !5T gang started forming in the mid 1980's", 0),
#  ('!Square-free elements may be also characterized using their prime decomposition',
#   0),
#  ('Server-specific keys issued by trusted authorities are merged into the !Keyfile along with the trusted root certificates',
#   0),
#  ("In summer 2008 !Vain will play at the 2nd annual 80's rock festival, Rocklahoma",
#   0),
#  ('The decree of !Nullity may therefore be no more than a declaration that no marriage had ever come into being, i.e',
#   0),
#  ('In 2005 !Elvstroem covered 166 mares, at AUD$38,500.00 per service', 0),
#  ('One could imagine a !Jug being made from nearly any watertight material, but most jugs throughout history have been made from clay, glass, or plastic',
#   0),
#  ('A young male horse is considered a !Colt even if he is gelded', 0),
#  ('Almost all buds are located in !Axillary positions, for example', 0),
#  ('They are divided into the Abbala (camel-herding) !Rizeigat, who live in northern Darfur and Chad, and the Baggara (cattle-herders) who inhabit south-east Darfur',
#   0),
#  ('Its original name was IPOD for Information and Product on Demand, but as they were creating their business cards they changed it to !Peapod on a whim',
#   0),
#  ('A large example of a Bronze Age Minoan !Temenos is at the Juktas Sanctuary of the palace of Knossos on ancient Crete in present day Greece, the temple having a massive northern temenos',
#   0),
#  ('The American families have differing family origins in the United States- the !Habersack families from Ohio and Massachusetts find roots in Fulda, Germany; the Michigan Habersacks have roots in Hungary; and the Maryland Habersack families have ancestry in Lieblos, Germany- now called Gr\\xcc\\xb0\\xef\\xbf\\xbdndau',
#   0),
#  ('Between 1978 and 1988, there were 186 cases of !Amineptine addiction reported to the French Regional Centres of Pharmacovigilance; an analysis of 155 of those cases found that they were predominantly female, and that two-thirds of cases had known risk factors for addiction',
#   0),
#  ('!Poseidon returned as a 5 year old for one last campaign', 0),
#  ('In 1970, following the Second Vatican Council, a revision of the Roman Breviary discontinued the use of !Nocturns when the office of Matins was reformed as the Office of Readings',
#   0),
#  ('After the reform of the Liturgy of the Hours following the Second Vatican Council, the !Invitatory is said either before the Office of Readings or Lauds, whichever is said first in a liturgical day',
#   0),
#  ('Chief Minister V S Achutanandan also gave an assurance to people affected by poisoning, "that the government would chalk out a plan to take care of treatment, food and other needs of the affected persons and that its promise of rehabilitation of victims would be honoured." A shipment of about 10 tonnes of !Endosulfan was illegally stowed on the ill-fated MV Princess of the Stars, a ferry that sank off the waters of Romblon (Sibuyan Island), Philippines during a storm in June 2008',
#   0),
#  ('In the aftermath of the war, !Akira was placed into cryostasis', 0),
#  ('!Coldsnap replaced Homelands in the Ice Age block', 0),
#  ('!Philopatry can manifest itself in several ways', 0),
#  ('In 1309 the !Schnabelburg was destroyed by the Habsburgs, in revenge for the participation of Walter von Eschenbach in the murder of Albert I of Germany',
#   0),
#  ('The foliage is the basis of a style of architectural ornamentation; see !Acanthus (ornament)',
#   0),
#  ('The sea around !Narsaq is full of marine life, including whales, salmon, and seals',
#   0),
#  ('Towns along the !Emscher include Dortmund, Castrop-Rauxel, Herne, Gelsenkirchen, Essen, Bottrop, Recklinghausen, Oberhausen and Dinslaken, where it flows into the Rhine',
#   0),
#  ('The word is possibly identical with an old name !Matrass (Fr. materas, matelas) for the bolt or quarrel of a cross-bow',
#   0),
#  ('In 1977, !Korvac reappears in Thor Annual #6, written by Roger Stern and art by Sal Buscema',
#   0),
#  ('Forbin asks +Colossus why his new synthesised voice has a British accent',
#   0),
#  ('$Colonel ranks above lieutenant colonel and below brigadier general', 0),
#  ('Some non-military personnel may be appointed to the position, thereby holding an Honorary rank of !Colonel for the duration of the appointment, though usually with the Territorial Army units',
#   0),
#  ('!Nek records and performs in both Italian and Spanish', 0),
#  ('!Anasol says that her greatest inspiration is the post Ray of Light work of Madonna',
#   0),
#  ('The !Waistline of a garment is often used to accentuate different features',
#   0),
#  ('The !FROLINAT, of which Goukouni was still nominally the head, dissolved itself on January 14, 1993',
#   0),
#  ('!XAMPP also provides support for creating and manipulating databases in MySQL and SQLite among others',
#   0),
#  ('Unlike the 6L6, (EIA base 7AC) the !EL34 has its grid 3 connection brought out to a separate Pin (Pin 1) (EIA base 8ET) and its heater draws 1.5 Amps compared to the 0.9 Amp heater in the 6L6',
#   0),
#  ("!Myx Philippines is known for featuring the music videos' lyrics on-screen, allowing the viewers to sing along",
#   0),
#  ('Also, !SkyCable launches an infomercial about their Digibox product, seen on MySky Channel 33',
#   0),
#  ("The circuit was developed in the early 1920's by Alan Hazeltine and made by a group of more than 20 firms that were licensed to produce Hazeltine-!Neutrodyne receivers known as the Independent Radio Manufacturers",
#   0),
#  ('The !Bisharin tend animals, including camels, sheep, goats, buffalo, and cattle',
#   0),
#  ('Braides: !\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd-convergence for beginners',
#   0),
#  ('In programming mode, the !TI-59 simply recorded key presses', 0),
#  ('There are more plans for !Ruwais and its lead by ADNOC (Abu Dhabi National Oil Company)',
#   0),
#  ("!Wiz transforms into Dark\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbds wings and is also able to transform into Daisuke or Dark (although more commonly Daisuke when his feelings causes him to gain Dark's appearance, but with Dark asleep, Daisuke keeps his personality)",
#   0),
#  ('Thus !Pradakshina is done around Tulsi plant and Peepal tree', 0),
#  ("Howard Stern, a Soupy Sales fan, referred to Brad Pitt and Angelina Jolie's new baby as Shiloh !Kvetch on his June 7, 2006 radio show",
#   0),
#  ('Generally shops and businesses are closed on !Poya Days, and the sale of alcohol and meat is forbidden',
#   0),
#  ('This is the second such series to spin out of the !Soulfire limited series',
#   0),
#  ('Primates are phylogenetically divided into Strepsirrhini ("curly-nosed" primates with rhinariums, which is the ancestral condition) and Haplorrhini ("simple-nosed" primates which have replaced the !Rhinarium with a more mobile, continuous, dry upper lip)',
#   0),
#  ('The first ever !Jugger international tournament took place in Hamburg, Germany on 20 May, 2007 between the Irish team Setanta and a number of the Northern German teams',
#   0),
#  ('Designing an adequate !Diffuser on a rebreather is much easier than on open-circuit scuba',
#   0),
#  ('!Jobs.ac.uk also has a strong working relationship with The Association of Commonwealth Universities',
#   0),
#  ('In the case of the ancient universities of Scotland the !Principal is President of the Academic Senate',
#   0),
#  ('When a !Conservator had been chosen by regulars he could not be removed for five years without cause',
#   0),
#  ('!Sezam BBS was founded on November 11 1989 as one of many one phone line / night only Bulletin Board Systems in Belgrade, Yugoslavia',
#   0),
#  ('Letizia Ortiz Rocasolano worked as a !Telediario newscaster before engaging and marrying Prince of Asturias Felipe de Borb\\xcc\\xb0\\xef\\xbf\\xbd\\xef\\xbf\\xbdn',
#   0),
#  ('In 2008, the History Channel aired an episode of Deep Sea Detectives titled Underwater Train Wreck in which they claim to have found two !Pioneer locomotives on the sea bottom off the coast of New Jersey',
#   0),
#  ('The Theory of Constraints and !Throughput accounting explicitly avoid that trap',
#   0),
#  ("When a page with a recordset is created by some web design software, an .!Mno file is created in the site's _notes folder",
#   0),
#  ('!Geldern has the largest Whitsun funfair of the lower Rhine, a street party in summer, and a Christmas Market',
#   0),
#  ('!Crosstalk is usually caused by undesired capacitive, inductive, or conductive coupling from one circuit, part of a circuit, or channel, to another',
#   0),
#  ('It has been developed at the Expertise Centre for Digital Media (Hasselt University, Belgium) and can render a !UIML document using different widget sets and different platforms',
#   0),
#  ('He was born in !Prigrevica in 1972', 0),
#  ('However, the Modern Indians have seen how adversely the Coalition States have responded to somebody else utilizing "their" !SAMAS designs',
#   0),
#  ('During WW2 these !Tanks were supplemented by several dozen imported German vehicles',
#   0),
#  ('Very few places in !Limbo are stable enough for normal travel', 0),
#  ('!Libera is associated with Persephone of Greek mythology', 0),
#  ('The !TRICARE Management Activity contracts with several large health insurance corporations to provide claims processing, customer service and other administrative functions to the TRICARE program',
#   0),
#  ('The net effect of !Disemvoweling text is to render it illegible or legible only through significant cognitive effort, thus suppressing unwanted comments and discouraging such comments from being made in future',
#   0),
#  ('The release of !Buzzsaw in Cybertron Deluxe wave 3.5 was packaged with a DVD containing the third episode of Transformers: Cybertron, called "Hidden"',
#   0),
#  ("After Strange manipulated the trio into forming the !Nightstalkers, the team fought the many supernatural enemies that were emerging, including the Lilin; Meatmarket; HYDRA's Department of Occult Armaments (DOA) and its renegade Dracula clone, Bloodstorm, who slaughtered that division, including its chief, Lt",
#   0),
#  ('The composition of the water in !Labinsk is reported to resemble the composition of Baden-Baden mineral waters',
#   0),
#  ('The !Siren of the title is the call of Datatsushi, summoning the residents of Hanuda to immerse themselves in the red water, thus creating an army of subordinates called nihongo',
#   0),
#  ('!Rage left after a brief scuffle, but ended up assisting the Avengers in their next mission',
#   0),
#  ('!Indican interferes with many commercial procedures for measuring total bilirubin which can be a problem for renal failure patients where blood indican levels are raised',
#   0),
#  ('The synonyms remainderer, remainderperson, and remainor are found in many legal dictionaries, but despite any political correctness, the terms Remainderwoman and Remainderperson are not used in practice: females in the position of a !Remainderman are also termed remaindermen',
#   0),
#  ('Some offer experienced riders the chance to ride along !Woolacombe Sands',
#   0),
#  ('!WHOI DT2 offers The Daily Buzz newscast, weekday mornings from 6 to 9 AM',
#   0),
#  ('"The History of !VAW-122," The Hook Summer 1996 Burgess, Rick "Lest We Forget: VAW-122" Naval Institute Proceedings September 2003',
#   0),
#  ('Features that determine the nature of a !Truel include', 0),
#  ('Report on a revised plan for the town and region of !Gandhidham, Kutch India, prepared for the Government of India Ministry of Transport, and the United States Department of State',
#   0),
#  ('!Papoose made his first attempts at rapping at the age of eleven', 0),
#  ('!Wink was re-introduced several months later as with new packaging as CPlus Wink Twist, a re-formulation that is slightly sweeter than the original',
#   0),
#  ('Persondata DEFAULTSORT:!Verbs   US-hiphop-bio-stub', 0),
#  ('A sequel called !BioMetal Gust was released for the Sega Saturn in 1997, included with the Dezaemon 2 pack',
#   0),
#  ('!Rara in Haiti is often used for political purposes, with candidates commissioning songs praising them and their campaigns',
#   0),
#  ('Zul karan, the second son of !Churaman said to his brother, \\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd Give me too a share in those goods and admit me as partner.\\xcc\\xa2\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd A verbal dispute followed and Muhkam made ready to resist by force',
#   0),
#  ('The !L\\xcc\\xb0\\xef\\xbf\\xbdcuma is exported all around the world', 0),
#  ('Each different kind of !Dan has their own unique characteristic', 0),
#  ('In the poem, an !Albatross starts to follow a ship, and is seen as a good omen',
#   0),
#  ('Occasionally, the !Toxicophore requires bioactivation, modified by an enzyme, to produce a more reactive chemical species that is able to covalently bind to cellular macromolecules',
#   0),
#  ('$D-Loc is a member of Kingspade', 0),
#  ("During this period the frequency of !Creepy and Warren's other magazines was upped to nine issues per year",
#   0),
#  ('In February 2008 it became apparent that Match would face fresh circulation challenges when it was announced that the BBC would once again be launching !Match Of The Day magazine into the weekly football marketplace and Shoot declared their intention to return to weekly publication',
#   0),
#  ('The !Diolkos remained reportedly in regular service until at least the middle of the 1st century AD, after which no more written references appear',
#   0),
#  ('In the drama, Ling merely stares at !Mars for a long time before Daye comes and calls for him to go',
#   0),
#  ('In the Japanese version, the character\\\'s voice is only credited as "Herself"; it is unknown who voices !Ulala in the Japanese version',
#   0),
#  ('!Idir was joined by a number of stars and thousands of Algerian and French fans who turned out to "Le Z\\xcc\\xb0\\xef\\xbf\\xbdnith" to support the population in Kabylia',
#   0),
#  ('While !Weighting may be applied to a set of data, for example epidemiological data, it is more commonly applied to measurements of light, heat, sound, gamma radiation, in fact any stimulus that is spread over a spectrum of frequencies',
#   0),
#  ('!Akoko takes a large percentage of local governments in Ondo state', 0),
#  ('Looshkin often plays cruel, sadistic, and nonsensical pranks on !Bear, and it is not uncommon for faeces and dismemberment to come into play',
#   0),
#  ('The S\\xcc\\xb0\\xef\\xbf\\xbdzanne flora is a fossil assemblage preserved in freshwater limestone deposits at S\\xcc\\xb0\\xef\\xbf\\xbdzanne, laid down during the !Thanetian faunal stage, when Europe enjoyed a tropical climate',
#   0),
#  ('Less often, the Middle Eocene is not used and the !Lutetian is united with the Ypresian in the Early Eocene',
#   0),
#  ('As sound elements are mixed and combined together the process necessitates "re-recording" all of the audio elements, such as dialogue, music, sound effects, by the sound !Re-recording mixer(s) to achieve the desired end result, which is the final soundtrack that the audience hears when the finished film is played',
#   0),
#  ('Although strides have recently been made in early diagnosis, !Blepharospasm is often initially mis-diagnosed as allergies or "dry eye syndrome"',
#   0),
#  ('Like all sounding rockets, !MSSTA flew for approximately 14 minutes per mission, about 5 minutes of which were in space -- just enough time to test a new technology or yield "first results" science',
#   0),
#  ('The Khaniqahi !Nimatullahi also publish in Persian, English and other languages, Dr',
#   0),
#  ...]
