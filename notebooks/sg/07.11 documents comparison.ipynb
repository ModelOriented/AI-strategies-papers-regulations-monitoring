# %%
# !pip install pdfminer.six
# Out:
# ...
#      |████████████████████████████████| 5.6 MB 2.8 MB/s
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/stanislaw/repos/AI-strategies-papers-regulations-monitoring/.venv/bin/python -m pip install --upgrade pip' command.

# %%
from pdfminer.high_level import extract_text,

# %%
ai_pl = extract_text('Polityka AI - dokument - wersja ostateczna opublikowana RCL_GRAI.pdf')

# %%
ai_pl.replace(' \n', ' ').replace('  ', ' ').split('\n')
# Out:
# ['Załącznik do uchwały nr 196 Rady Ministrów z dnia 28 grudnia 2020 r. (poz.   ) ',
#  'Polityka dla rozwoju ',
#  'sztucznej inteligencji ',
#  'w Polsce ',
#  'od roku 2020 ',
#  '1 ',
#  '   \x0cWstęp ',
#  'Polityka AI w Polsce w relacjach do dokumentów strategicznych ',
#  'Niniejsza „Polityka dla rozwoju sztucznej inteligencji w Polsce od 2020 roku”, zwana dalej „Polityką AI”, jest zaprojektowana w spójności z kierunkowymi działaniami państwa, Unii Europejskiej (UE), a także w konsekwencji przyjęcia dokumentów strategicznych organizacji międzynarodowych, których Polska jest członkiem, takich jak Organizacja Współpracy Gospodarczej i Rozwoju (OECD). W szczególności Polityka AI uwzględnia cele zdefiniowane w następujących dokumentach strategicznych: ',
# ...
